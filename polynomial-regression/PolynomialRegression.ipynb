# %% [markdown]
# Importing the libraries required

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Importing the dataset

# %%
dataset=pd.read_csv('Position_Salaries.csv')
X=dataset.iloc[:,1:-1].values
y=dataset.iloc[:,-1].values

# %% [markdown]
# Training the linear regression model

# %%
from sklearn.linear_model import LinearRegression
regressor_linear=LinearRegression()
regressor_linear.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# Training the polynomial regression model

# %%
from sklearn.preprocessing import PolynomialFeatures
regressor_poly=PolynomialFeatures(degree=5)
X_poly=regressor_poly.fit_transform(X)
new_linear_regressor=LinearRegression()
new_linear_regressor.fit(X_poly,y)
# Out:
# LinearRegression()

# %% [markdown]
# Visualising the linear regression results

# %%
plt.scatter(X,y,color='blue')
plt.plot(X,regressor_linear.predict(X),color="green")
plt.title("Linear Regression")
plt.xlabel("Position Level")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# Visualising the polynomial regression results

# %%
plt.scatter(X,y,color='blue')
plt.plot(X,new_linear_regressor.predict(X_poly),color="red")
plt.title("Polynomial Regression")
plt.xlabel("Position Level")
plt.ylabel("Salary")
plt.show()
